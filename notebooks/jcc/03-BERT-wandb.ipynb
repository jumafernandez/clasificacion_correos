# %% [markdown]
# <a href="https://colab.research.google.com/github/jumafernandez/clasificacion_correos/blob/main/notebooks/jcc/03-BERT-wandb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # JCC: BERT con ajuste de hiperparámetros
#
# En esta notebook se presentan los experimentos sobre la estrategia de representación y técnica de aprendizaje *avanzada* utilizada para las JCC de  la Universidad Nacional de La Plata.
#
# Para ello vamos a tomar el texto de la consulta de los correos y aplicar BERT con el modelo pre-entrenado en español (BETO - Departamento de Computación de la Universidad de Chile).

# %% [markdown]
# ## Instalación de librerías
#
# Se instalan dos librerías que no están en el entorno Colab:
# - *simpletransformers* (para entrenar Bert),
# - requests (para consumir funciones propias de Github),
# - wget (para la descarga de archivos),
# - wandb (para la optimización de hiperparámetros).

# %%
# !pip install simpletransformers
# !pip install requests
# !pip install wget
# !pip install wandb

# %% [markdown]
# ### Funciones útiles
#
# Se cargan funciones útiles desde el repo https://github.com/jumafernandez/clasificacion_correos para la carga y balanceo del dataset.

# %%
import requests

# Se hace el request del raw del script python
url = 'https://raw.githubusercontent.com/jumafernandez/clasificacion_correos/main/scripts/jcc/funciones_dataset.py'
r = requests.get(url)

# Se guarda en el working directory
with open('funciones_dataset.py', 'w') as f:
    f.write(r.text)

# Se importan las funciones a utilizar
from funciones_dataset import get_clases, cargar_dataset, separar_x_y_rna

# %% [markdown]
# También se carga la función para preprocesar el texto que se usó en los otros modelos desde el repo: https://github.com/jumafernandez/clasificacion_correos.

# %%
import requests

# Se hace el request del raw del script python
url = 'https://raw.githubusercontent.com/jumafernandez/clasificacion_correos/main/scripts/jcc/funciones_preprocesamiento.py'
r = requests.get(url)

# Se guarda en el working directory
with open('funciones_preprocesamiento.py', 'w') as f:
    f.write(r.text)

# Se importan las funciones a utilizar
from funciones_preprocesamiento import preprocesar_correos_bert

# %% [markdown]
# ## Carga del dataset con los correos
#
# Se cargan los datos y se realiza el balanceo de clases:

# %%
from funciones_dataset import get_clases, cargar_dataset
from os import path
import warnings
warnings.filterwarnings("ignore")

# Cantidad de clases
CANTIDAD_CLASES = 4

# Constantes con los datos
DS_DIR = 'https://raw.githubusercontent.com/jumafernandez/clasificacion_correos/main/data/consolidado_jcc/'
TRAIN_FILE = 'correos-train-80.csv'
TEST_FILE = 'correos-test-20.csv'

# Chequeo sobre si los archivos están en el working directory
download_files = not(path.exists(TRAIN_FILE))

etiquetas = get_clases()
train_df, test_df, etiquetas = cargar_dataset(DS_DIR, TRAIN_FILE, TEST_FILE, download_files, 'clase', etiquetas, CANTIDAD_CLASES, 'Otras Consultas')
# Out:
# Se inicia descarga de los datasets.
#
# El conjunto de entrenamiento tiene la dimensión: (800, 24)
# El conjunto de testeo tiene la dimensión: (200, 24)

# %% [markdown]
# ### Pre-procesamiento de los datos
#
# Se preparan los datos para el entrenamiento de BERT:

# %%
train_df = train_df[['Consulta', 'clase']]
train_df.columns = ['text', 'labels']
test_df = test_df[['Consulta', 'clase']]
test_df.columns = ['text', 'labels']

# Cambio los integers por las etiquetas
train_df.labels = etiquetas[train_df.labels]
test_df.labels = etiquetas[test_df.labels]

# Las vuelvo a pasar a números 0-N para evitar conflictos con simpletransformers
# Este paso está fijo para estos experimentos
dict_clases_id = {'Otras Consultas': 0,
                            'Ingreso a la Universidad': 1,
                            'Boleto Universitario': 2,
                            'Requisitos de Ingreso': 3}

train_df['labels'].replace(dict_clases_id, inplace=True)
test_df['labels'].replace(dict_clases_id, inplace=True)

# Muestro salida por consola
print('Existen {} clases: {}.'.format(len(train_df.labels.unique()), train_df.labels.unique()))
# Out:
# Existen 4 clases: [0 1 2 3].

# %% [markdown]
# ## Elección de un modelo monolenguaje pre-entrenado
#
# La librería *simpletransformers* se basa en la librería *Transformers* de HuggingFace. Esto permite utilizar todos los modelos pre-entrenados disponibles en la [Transformers library](https://huggingface.co/transformers/pretrained_models.html) que son provistos por toda la comunidad de desarrolladores. Para ver cuales son los modelos disponibles, se puede ingresar a [https://huggingface.co/models](https://huggingface.co/models).
#
# En nuestro caso, vamos a utilizar el modelo `dccuchile/bert-base-spanish-wwm-cased`. Este modelo está pre-entrenado por un equipo de investigadores del Departamento de Computación de la Universidad de Chile.

# %% [markdown]
# ### Optimización de hiperparámetros
#
# Se utiliza Sweep de wandb para la optimización de hiperparámetros.
#
# Para más información:
# https://simpletransformers.ai/docs/tips-and-tricks/#hyperparameter-optimization

# %%
import wandb

sweep_config = {
    "method": "bayes",  # grid, random
    "metric": {"name": "train_loss", "goal": "minimize"},
    "parameters": {
        "num_train_epochs": {"values": [2, 3, 4]},
        "learning_rate": {"min": 4e-5, "max": 4e-4},
    },
}

sweep_id = wandb.sweep(sweep_config, project="Bert_JCC2021")
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Create sweep with ID: 5ocb1k9j
# Sweep URL: https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j

# %% [markdown]
# Trackeo del logg de aprendizaje del Modelo:

# %%
import logging

logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# %% [markdown]
# ### Definición del Modelo para Clasificación
#
# Se carga el modelo pre-entrenado BETO con la respectiva definición de hiperparámetros para el entrenamiento:

# %%
from simpletransformers.classification import ClassificationModel

# Hiperparámetros
train_args = {
        'overwrite_output_dir': True,
        'reprocess_input_data': True,
        'evaluate_during_training': True,
        'fp16': True,
        'do_lower_case': True,
        'use_early_stopping': True,
        'manual_seed': 4,
        'use_multiprocessing': True,
        'train_batch_size': 16,
        'eval_batch_size': 8,
        'wandb_project': 'Bert_JCC2021',
        }

# %% [markdown]
# ## Entrenamiento
#
# Se entrena el modelo con el dataset de train en función de los hiperparámetros:

# %%
def train():
    # Se inicializa wandb
    wandb.init()

    # Creamos el ClassificationModel
    model = ClassificationModel(
        model_type='bert', 
    #    model_name='bert-base-multilingual-cased',
        model_name='dccuchile/bert-base-spanish-wwm-cased',
        num_labels=CANTIDAD_CLASES,
        use_cuda=False,
        args=train_args
    )

    # Se entrena el modelo
    model.train_model(train_df, eval_df=test_df)

    # Se evalúa el modelo
    model.eval_model(test_df)

    # Se sincroniza el run
    wandb.join()

wandb.agent(sweep_id, train)
# Out:
# INFO:wandb.agents.pyagent:Starting sweep agent: entity=None, project=None, count=None
# wandb: Agent Starting Run: p01pmrsz with config:
# wandb: 	learning_rate: 0.0003325194503654975
# wandb: 	num_train_epochs: 3
# wandb: Currently logged in as: jumafernandez (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">comic-sweep-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j</a><br/>
# Run page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/p01pmrsz" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/p01pmrsz</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_221048-p01pmrsz</code><br/><br/>
# INFO:filelock:Lock 139777078333776 acquired on /root/.cache/huggingface/transformers/cb7cedb04246e225d56ba26d207f1d1809b31a9bbe9b63103371d835c6ac0502.f4e4777229bac528fa2a8d4833e2ef53624e985ebde0fd527064a5cc7c50832b.lock
# Downloading:   0%|          | 0.00/648 [00:00<?, ?B/s]
# INFO:filelock:Lock 139777078333776 released on /root/.cache/huggingface/transformers/cb7cedb04246e225d56ba26d207f1d1809b31a9bbe9b63103371d835c6ac0502.f4e4777229bac528fa2a8d4833e2ef53624e985ebde0fd527064a5cc7c50832b.lock
# INFO:filelock:Lock 139777044493200 acquired on /root/.cache/huggingface/transformers/52382cbe7c1587c6b588daa81eaf247c5e2ad073d42b52192a8cd4202e7429b6.a88ccd19b1f271e63b6a901510804e6c0318089355c471334fe8b71b316a30ab.lock
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# INFO:filelock:Lock 139777044493200 released on /root/.cache/huggingface/transformers/52382cbe7c1587c6b588daa81eaf247c5e2ad073d42b52192a8cd4202e7429b6.a88ccd19b1f271e63b6a901510804e6c0318089355c471334fe8b71b316a30ab.lock
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:filelock:Lock 139777044492688 acquired on /root/.cache/huggingface/transformers/6761cd0c3d282272f598fcc1fa8c4ecfff8c18762ec8acb40f9cbb562cb0901e.6587bde86239957281af55b2f7e564df111a2b4f9dfc0ad884f13ea7106e4dfb.lock
# Downloading:   0%|          | 0.00/242k [00:00<?, ?B/s]
# INFO:filelock:Lock 139777044492688 released on /root/.cache/huggingface/transformers/6761cd0c3d282272f598fcc1fa8c4ecfff8c18762ec8acb40f9cbb562cb0901e.6587bde86239957281af55b2f7e564df111a2b4f9dfc0ad884f13ea7106e4dfb.lock
# INFO:filelock:Lock 139777035150096 acquired on /root/.cache/huggingface/transformers/44de7af89c157bf67367a71105165d92bebe0585543739a918e3870d25484c27.6a099cd4b12bf7db174fffe48b004eb919c325f108e0c36176a0fe0ad1848d31.lock
# Downloading:   0%|          | 0.00/480k [00:00<?, ?B/s]
# INFO:filelock:Lock 139777035150096 released on /root/.cache/huggingface/transformers/44de7af89c157bf67367a71105165d92bebe0585543739a918e3870d25484c27.6a099cd4b12bf7db174fffe48b004eb919c325f108e0c36176a0fe0ad1848d31.lock
# INFO:filelock:Lock 139777044493840 acquired on /root/.cache/huggingface/transformers/9848a00af462c42dfb4ec88ef438fbab5256330f7f6f50badc48d277f9367d49.f982506b52498d4adb4bd491f593dc92b2ef6be61bfdbe9d30f53f963f9f5b66.lock
# Downloading:   0%|          | 0.00/134 [00:00<?, ?B/s]
# INFO:filelock:Lock 139777044493840 released on /root/.cache/huggingface/transformers/9848a00af462c42dfb4ec88ef438fbab5256330f7f6f50badc48d277f9367d49.f982506b52498d4adb4bd491f593dc92b2ef6be61bfdbe9d30f53f963f9f5b66.lock
# INFO:filelock:Lock 139777189382608 acquired on /root/.cache/huggingface/transformers/ca34e6c1251888a8ed98da2a454f869d28e3438eef67c2f93aa8133459ac08a3.0e90f656d0426b15b4927d1fe8ca5ec4c2e7b0d0e878c9153c3ddc6ed9bbed3c.lock
# Downloading:   0%|          | 0.00/364 [00:00<?, ?B/s]
# INFO:filelock:Lock 139777189382608 released on /root/.cache/huggingface/transformers/ca34e6c1251888a8ed98da2a454f869d28e3438eef67c2f93aa8133459ac08a3.0e90f656d0426b15b4927d1fe8ca5ec4c2e7b0d0e878c9153c3ddc6ed9bbed3c.lock
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/800 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_128_4_2
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/50 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.6667790263652669, 'eval_loss': 0.6182582986354828}
# <br/>Waiting for W&B process to finish, PID 317<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210405_221048-p01pmrsz/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210405_221048-p01pmrsz/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>0.52839</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>global_step</td><td>50</td></tr><tr><td>_runtime</td><td>979</td></tr><tr><td>_timestamp</td><td>1617661627</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>mcc</td><td>0.66678</td></tr><tr><td>train_loss</td><td>0.52839</td></tr><tr><td>eval_loss</td><td>0.61826</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>▁</td></tr><tr><td>lr</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁</td></tr><tr><td>_runtime</td><td>▁▄███</td></tr><tr><td>_timestamp</td><td>▁▄███</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr><tr><td>mcc</td><td>▁</td></tr><tr><td>train_loss</td><td>▁</td></tr><tr><td>eval_loss</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 4 media file(s), 3 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">comic-sweep-1</strong>: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/p01pmrsz" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/p01pmrsz</a><br/>
# wandb: Agent Starting Run: k0rxcw3q with config:
# wandb: 	learning_rate: 0.00024445254549075417
# wandb: 	num_train_epochs: 3
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">morning-sweep-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j</a><br/>
# Run page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/k0rxcw3q" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/k0rxcw3q</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_222716-k0rxcw3q</code><br/><br/>
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/800 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_128_4_2
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/50 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.6667790263652669, 'eval_loss': 0.6182582986354828}
# <br/>Waiting for W&B process to finish, PID 556<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210405_222716-k0rxcw3q/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210405_222716-k0rxcw3q/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>0.52839</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>global_step</td><td>50</td></tr><tr><td>_runtime</td><td>964</td></tr><tr><td>_timestamp</td><td>1617662600</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>mcc</td><td>0.66678</td></tr><tr><td>train_loss</td><td>0.52839</td></tr><tr><td>eval_loss</td><td>0.61826</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>▁</td></tr><tr><td>lr</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁</td></tr><tr><td>_runtime</td><td>▁▄███</td></tr><tr><td>_timestamp</td><td>▁▄███</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr><tr><td>mcc</td><td>▁</td></tr><tr><td>train_loss</td><td>▁</td></tr><tr><td>eval_loss</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 4 media file(s), 3 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">morning-sweep-2</strong>: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/k0rxcw3q" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/k0rxcw3q</a><br/>
# wandb: Agent Starting Run: 52ypeu77 with config:
# wandb: 	learning_rate: 0.00013388952193487948
# wandb: 	num_train_epochs: 2
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">misunderstood-sweep-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j</a><br/>
# Run page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/52ypeu77" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/52ypeu77</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_224330-52ypeu77</code><br/><br/>
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/800 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_128_4_2
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/50 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.6667790263652669, 'eval_loss': 0.6182582986354828}
# <br/>Waiting for W&B process to finish, PID 799<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210405_224330-52ypeu77/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210405_224330-52ypeu77/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>0.52839</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>global_step</td><td>50</td></tr><tr><td>_runtime</td><td>983</td></tr><tr><td>_timestamp</td><td>1617663594</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>mcc</td><td>0.66678</td></tr><tr><td>train_loss</td><td>0.52839</td></tr><tr><td>eval_loss</td><td>0.61826</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>▁</td></tr><tr><td>lr</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁</td></tr><tr><td>_runtime</td><td>▁▄███</td></tr><tr><td>_timestamp</td><td>▁▄███</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr><tr><td>mcc</td><td>▁</td></tr><tr><td>train_loss</td><td>▁</td></tr><tr><td>eval_loss</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 4 media file(s), 3 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">misunderstood-sweep-3</strong>: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/52ypeu77" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/52ypeu77</a><br/>
# wandb: Agent Starting Run: a9j6d8p8 with config:
# wandb: 	learning_rate: 0.00038333537789076426
# wandb: 	num_train_epochs: 4
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">brisk-sweep-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j</a><br/>
# Run page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/a9j6d8p8" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/a9j6d8p8</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_230004-a9j6d8p8</code><br/><br/>
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/800 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_128_4_2
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/50 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.6667790263652669, 'eval_loss': 0.6182582986354828}
# <br/>Waiting for W&B process to finish, PID 1028<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210405_230004-a9j6d8p8/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210405_230004-a9j6d8p8/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>0.52839</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>global_step</td><td>50</td></tr><tr><td>_runtime</td><td>967</td></tr><tr><td>_timestamp</td><td>1617664571</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>mcc</td><td>0.66678</td></tr><tr><td>train_loss</td><td>0.52839</td></tr><tr><td>eval_loss</td><td>0.61826</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>▁</td></tr><tr><td>lr</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁</td></tr><tr><td>_runtime</td><td>▁▄███</td></tr><tr><td>_timestamp</td><td>▁▄███</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr><tr><td>mcc</td><td>▁</td></tr><tr><td>train_loss</td><td>▁</td></tr><tr><td>eval_loss</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 4 media file(s), 3 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">brisk-sweep-4</strong>: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/a9j6d8p8" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/a9j6d8p8</a><br/>
# wandb: Agent Starting Run: wy7r01zy with config:
# wandb: 	learning_rate: 4.715089759221623e-05
# wandb: 	num_train_epochs: 2
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">young-sweep-5</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j</a><br/>
# Run page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/wy7r01zy" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/wy7r01zy</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_231623-wy7r01zy</code><br/><br/>
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/800 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_128_4_2
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/50 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.6667790263652669, 'eval_loss': 0.6182582986354828}
# <br/>Waiting for W&B process to finish, PID 1131<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210405_231623-wy7r01zy/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210405_231623-wy7r01zy/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>0.52839</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>global_step</td><td>50</td></tr><tr><td>_runtime</td><td>988</td></tr><tr><td>_timestamp</td><td>1617665571</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>mcc</td><td>0.66678</td></tr><tr><td>train_loss</td><td>0.52839</td></tr><tr><td>eval_loss</td><td>0.61826</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>▁</td></tr><tr><td>lr</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁</td></tr><tr><td>_runtime</td><td>▁▄███</td></tr><tr><td>_timestamp</td><td>▁▄███</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr><tr><td>mcc</td><td>▁</td></tr><tr><td>train_loss</td><td>▁</td></tr><tr><td>eval_loss</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 4 media file(s), 3 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">young-sweep-5</strong>: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/wy7r01zy" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/wy7r01zy</a><br/>
# wandb: Agent Starting Run: g23hs38y with config:
# wandb: 	learning_rate: 0.00016629698128897924
# wandb: 	num_train_epochs: 4
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">clear-sweep-6</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j</a><br/>
# Run page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/g23hs38y" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/g23hs38y</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_233303-g23hs38y</code><br/><br/>
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/800 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_128_4_2
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/50 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.6667790263652669, 'eval_loss': 0.6182582986354828}
# <br/>Waiting for W&B process to finish, PID 1194<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210405_233303-g23hs38y/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210405_233303-g23hs38y/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>0.52839</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>global_step</td><td>50</td></tr><tr><td>_runtime</td><td>980</td></tr><tr><td>_timestamp</td><td>1617666563</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>mcc</td><td>0.66678</td></tr><tr><td>train_loss</td><td>0.52839</td></tr><tr><td>eval_loss</td><td>0.61826</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>▁</td></tr><tr><td>lr</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁</td></tr><tr><td>_runtime</td><td>▁▄███</td></tr><tr><td>_timestamp</td><td>▁▄███</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr><tr><td>mcc</td><td>▁</td></tr><tr><td>train_loss</td><td>▁</td></tr><tr><td>eval_loss</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 4 media file(s), 3 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">clear-sweep-6</strong>: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/g23hs38y" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/g23hs38y</a><br/>
# wandb: Agent Starting Run: e727o60u with config:
# wandb: 	learning_rate: 0.0003338003468045088
# wandb: 	num_train_epochs: 2
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">vague-sweep-7</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j</a><br/>
# Run page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/e727o60u" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/e727o60u</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_234935-e727o60u</code><br/><br/>
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/800 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_128_4_2
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/50 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.6667790263652669, 'eval_loss': 0.6182582986354828}
# <br/>Waiting for W&B process to finish, PID 1257<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210405_234935-e727o60u/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210405_234935-e727o60u/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>0.52839</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>global_step</td><td>50</td></tr><tr><td>_runtime</td><td>1007</td></tr><tr><td>_timestamp</td><td>1617667582</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>mcc</td><td>0.66678</td></tr><tr><td>train_loss</td><td>0.52839</td></tr><tr><td>eval_loss</td><td>0.61826</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>▁</td></tr><tr><td>lr</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁</td></tr><tr><td>_runtime</td><td>▁▄███</td></tr><tr><td>_timestamp</td><td>▁▄███</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr><tr><td>mcc</td><td>▁</td></tr><tr><td>train_loss</td><td>▁</td></tr><tr><td>eval_loss</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 4 media file(s), 3 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">vague-sweep-7</strong>: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/e727o60u" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/e727o60u</a><br/>
# wandb: Agent Starting Run: kl98fv9z with config:
# wandb: 	learning_rate: 0.00011282659154906465
# wandb: 	num_train_epochs: 2
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">ethereal-sweep-8</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j</a><br/>
# Run page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/kl98fv9z" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/kl98fv9z</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210406_000635-kl98fv9z</code><br/><br/>
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/800 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_128_4_2
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/50 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.6667790263652669, 'eval_loss': 0.6182582986354828}
# <br/>Waiting for W&B process to finish, PID 1322<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210406_000635-kl98fv9z/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210406_000635-kl98fv9z/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>0.52839</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>global_step</td><td>50</td></tr><tr><td>_runtime</td><td>985</td></tr><tr><td>_timestamp</td><td>1617668580</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>mcc</td><td>0.66678</td></tr><tr><td>train_loss</td><td>0.52839</td></tr><tr><td>eval_loss</td><td>0.61826</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>▁</td></tr><tr><td>lr</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁</td></tr><tr><td>_runtime</td><td>▁▄███</td></tr><tr><td>_timestamp</td><td>▁▄███</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr><tr><td>mcc</td><td>▁</td></tr><tr><td>train_loss</td><td>▁</td></tr><tr><td>eval_loss</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 4 media file(s), 3 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ethereal-sweep-8</strong>: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/kl98fv9z" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/kl98fv9z</a><br/>
# wandb: Agent Starting Run: j32qilps with config:
# wandb: 	learning_rate: 0.0002744680937267031
# wandb: 	num_train_epochs: 2
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">misunderstood-sweep-9</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j</a><br/>
# Run page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/j32qilps" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/j32qilps</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210406_002315-j32qilps</code><br/><br/>
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/800 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_128_4_2
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/50 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_4_2
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.6667790263652669, 'eval_loss': 0.6182582986354828}
# <br/>Waiting for W&B process to finish, PID 1501<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210406_002315-j32qilps/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210406_002315-j32qilps/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>0.52839</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>global_step</td><td>50</td></tr><tr><td>_runtime</td><td>1016</td></tr><tr><td>_timestamp</td><td>1617669611</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>mcc</td><td>0.66678</td></tr><tr><td>train_loss</td><td>0.52839</td></tr><tr><td>eval_loss</td><td>0.61826</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>▁</td></tr><tr><td>lr</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁</td></tr><tr><td>_runtime</td><td>▁▄███</td></tr><tr><td>_timestamp</td><td>▁▄███</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr><tr><td>mcc</td><td>▁</td></tr><tr><td>train_loss</td><td>▁</td></tr><tr><td>eval_loss</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 4 media file(s), 3 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">misunderstood-sweep-9</strong>: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/j32qilps" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/j32qilps</a><br/>
# wandb: Agent Starting Run: ehl3vk1e with config:
# wandb: 	learning_rate: 0.00034418130472676904
# wandb: 	num_train_epochs: 3
# wandb: wandb version 0.10.25 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">noble-sweep-10</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/sweeps/5ocb1k9j</a><br/>
# Run page: <a href="https://wandb.ai/jumafernandez/Bert_JCC2021/runs/ehl3vk1e" target="_blank">https://wandb.ai/jumafernandez/Bert_JCC2021/runs/ehl3vk1e</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210406_004026-ehl3vk1e</code><br/><br/>
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/800 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_128_4_2
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/50 [00:00<?, ?it/s]
